# %%
Location= input("enter your Location: ")
town_list={"Douala":82,"Yaounde":89,"Limbe":56,"Kribi":70,"Bamenda":60,"Nkongsamba":53 }
score=town_list[Location]
if score > 60:
    print("safe")
else:
    print("high risk")
# Out:
# enter your Location: Limbe
# high risk
